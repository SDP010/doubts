# %%
import pandas as pd

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
test_data = requests.get(url)
test_data
# Out:
# <Response [200]>

# %%
jason_data = test_data.json()

# %%
df = pd.DataFrame(jason_data)

# %%
df
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df.to_csv("original_data1.csv")

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 601A-2EE2
#
#  Directory of C:\Users\pauls\iNeuron\prog_assignments
#
# 14-04-2022  20:12    <DIR>          .
# 31-03-2022  11:19    <DIR>          ..
# 02-04-2022  11:34    <DIR>          .idea
# 14-04-2022  20:06    <DIR>          .ipynb_checkpoints
# 29-03-2022  11:49               702 array prog.py
# 28-03-2022  11:28               511 calc.log
# 29-03-2022  01:44             1,005 calc1.log
# 04-04-2022  12:25            51,867 car.data
# 28-03-2022  00:42            11,778 comp_lcm.log
# 27-03-2022  20:49               294 comp_lcm1.log
# 29-03-2022  02:08               446 conversion.py
# 13-04-2022  16:03           142,821 final_data
# 13-04-2022  16:18           142,821 final_data.csv
# 14-04-2022  20:12           150,219 final_data1.csv
# 27-03-2022  14:38               800 hcf.py
# 13-04-2022  16:09           129,011 original_data
# 14-04-2022  20:08           136,366 original_data.csv
# ...

# %%
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'reactions', 'timeline_url',
#        'performed_via_github_app', 'draft', 'pull_request'],
#       dtype='object')

# %%
d_keys = df['user'][0].keys()

# %%
for i in d_keys :
    x = i
    i = []
#     print(i)
    for j in range(len(df)) :
        i.append(df['user'][j][x])
    df[x] = i

# %%
# REQUIRED OUTPUT

df
# Out:
#                                                   url  \
# 0        https://api.github.com/users/simonjayhawkins
# 1             https://api.github.com/users/brunorigal
# 2              https://api.github.com/users/mroeschke
# 3             https://api.github.com/users/joseortiz3
# 4                  https://api.github.com/users/ma3da
# 5                 https://api.github.com/users/kwhkim
# 6          https://api.github.com/users/galipremsagar
# 7                 https://api.github.com/users/Dr-Irv
# 8                 https://api.github.com/users/Moisan
# 9             https://api.github.com/users/maalgorium
# 10           https://api.github.com/users/andreareina
# 11  https://api.github.com/users/douglas-raillard-arm
# 12                https://api.github.com/users/Dr-Irv
# 13            https://api.github.com/users/joseortiz3
# 14                https://api.github.com/users/smarie
# 15               https://api.github.com/users/gwerbin
# ...

# %%
df.to_csv("final_data1.csv")
